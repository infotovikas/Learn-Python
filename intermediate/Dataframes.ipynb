# %% [markdown]
# <a href="https://colab.research.google.com/github/infotovikas/Learn-Python/blob/main/intermediate/Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Method 1: Specify Full Path To File

# %%
#Windows:
stats = pd.read_csv('/content/sample_data/SampleData.csv')

# %%
#1. Full Dataframe
stats
# Out:
#     Age  Gender     Occupation Income (USD)       Location Marital Status  \
# 0    25    Male       Employed       50,000       New York         Single
# 1    34  Female        Student       20,000    Los Angeles         Single
# 2    55    Male        Retired       40,000        Chicago        Married
# 3    28  Female       Employed       60,000  San Francisco        Married
# 4    42   Other  Self-employed     1,00,000          Miami       Divorced
# 5    38    Male       Employed       75,000        Houston         Single
# 6    67  Female        Retired       30,000        Phoenix        Widowed
# 7    23    Male        Student       15,000         Denver         Single
# 8    48  Female       Employed       85,000         Boston        Married
# 9    31    Male  Self-employed       55,000        Seattle        Married
# 10   37    Male  Self-employed       65,000          Texas        Married
#
#    Education Level
# 0        Bachelors
# 1      High School
# ...

# %%
# Method 2: Change Working Directory

# %%
import os

# %%
print(os.getcwd())
#os.chdir('c:\\Learning\\python\\sampledata.csv')
# Out:
# /content

# %%
### Exploring the Data

# %%
#2. No of Rows
len(stats)
# Out:
# 11

# %%
#3. See Columns
stats.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Income (USD)', 'Location',
#        'Marital Status', 'Education Level'],
#       dtype='object')

# %%
#4. No of Columns
len(stats.columns)
# Out:
# 7

# %%
#5. Top Rows
stats.head(6)   # remember the brackets
# Out:
#    Age  Gender     Occupation Income (USD)       Location Marital Status  \
# 0   25    Male       Employed       50,000       New York         Single
# 1   34  Female        Student       20,000    Los Angeles         Single
# 2   55    Male        Retired       40,000        Chicago        Married
# 3   28  Female       Employed       60,000  San Francisco        Married
# 4   42   Other  Self-employed     1,00,000          Miami       Divorced
# 5   38    Male       Employed       75,000        Houston         Single
#
#   Education Level
# 0       Bachelors
# 1     High School
# 2         Masters
# 3       Bachelors
# 4             PhD
# 5       Bachelors

# %%
#6. Bottom Rows
stats.tail(2)   # remember the brackets
# Out:
#     Age Gender     Occupation Income (USD) Location Marital Status  \
# 9    31   Male  Self-employed       55,000  Seattle        Married
# 10   37   Male  Self-employed       65,000    Texas        Married
#
#    Education Level
# 9        Bachelors
# 10         Masters

# %%
#7. Information on the columns
stats.info()  #like the str() function in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              11 non-null     int64
#  1   Gender           11 non-null     object
#  2   Occupation       11 non-null     object
#  3   Income (USD)     11 non-null     object
#  4   Location         11 non-null     object
#  5   Marital Status   11 non-null     object
#  6   Education Level  11 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 748.0+ bytes

# %%
#8. Get stats on the columns
stats.describe() #like summary() function in R
# Out:
#              Age
# count  11.000000
# mean   38.909091
# std    13.404884
# min    23.000000
# 25%    29.500000
# 50%    37.000000
# 75%    45.000000
# max    67.000000

# %%
#The above can more readable using Transpose() function
stats.describe().transpose()
# Out:
#      count       mean        std   min   25%   50%   75%   max
# Age   11.0  38.909091  13.404884  23.0  29.5  37.0  45.0  67.0

# %%
### Renaming of the Columns in Dataframe

# %%
stats.head(1)
# Out:
#    Age Gender Occupation Income (USD)  Location Marital Status Education Level
# 0   25   Male   Employed       50,000  New York         Single       Bachelors

# %%
stats.columns
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Income (USD)', 'Location',
#        'Marital Status', 'Education Level'],
#       dtype='object')

# %%
stats.columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
stats.head(1)
# Out:
#     a     b         c       d         e       f          g
# 0  25  Male  Employed  50,000  New York  Single  Bachelors

# %%
stats.columns = ['Age', 'Gender', 'Occupation', 'Income(USD)', 'Location',
       'MaritalStatus', 'EducationLevel']

# %%
stats.head(2)
# Out:
#    Age  Gender Occupation Income(USD)     Location MaritalStatus  \
# 0   25    Male   Employed      50,000     New York        Single
# 1   34  Female    Student      20,000  Los Angeles        Single
#
#   EducationLevel
# 0      Bachelors
# 1    High School
